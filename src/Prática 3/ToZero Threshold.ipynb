# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import Image

# %%
f = cv2.imread('einstein.jpg',cv2.IMREAD_GRAYSCALE)
x,y = f.shape

# %%
f_array = f.flatten()

# %%
T = np.mean(f_array)
T
# Out:
# 74.23342320023316

# %%
for i in range(x):
    for j in range(y):
        if(f[i][j] > T):
            f[i][j] = f[i][i]
        else:
            f[i][j] = 0

# %%
cv2.imwrite("f_toZero_threshold.jpg",f)
Image(filename='f_toZero_threshold.jpg')
